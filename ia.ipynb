# %% [markdown]
# <a href="https://colab.research.google.com/github/alejandrobernalchavez/progralll-2024-semi/blob/Bloque-3/ia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Entrenando una IA de conversor de temperatura

# %%
import tensorflow as tf
import pandas as pd

temp = pd.read_csv("/content/conversor2.csv", sep=";", encoding="utf-8")
print(temp, temp["f"])
# Out:
#      c      f
# 0  -50  -58.0
# 1  -40  -40.0
# 2  -30  -22.0
# 3  -20   -4.0
# 4  -15    5.0
# 5  -10   14.0
# 6   -5   23.0
# 7   -4   24.8
# 8   -3   26.6
# 9   -2   28.4
# 10  -1   30.2
# 11   0   32.0
# 12   1   33.8
# 13   2   35.6
# 14   3   37.4
# 15   4   39.2
# 16   5   41.0
# 17  10   50.0
# 18  15   59.0
# 19  20   68.0
# 20  30   86.0
# 21  40  104.0
# 22  50  122.0 0     -58.0
# 1     -40.0
# 2     -22.0
# 3      -4.0
# 4       5.0
# 5      14.0
# 6      23.0
# 7      24.8
# 8      26.6
# 9      28.4
# 10     30.2
# 11     32.0
# 12     33.8
# 13     35.6
# 14     37.4
# 15     39.2
# 16     41.0
# 17     50.0
# 18     59.0
# 19     68.0
# 20     86.0
# 21    104.0
# 22    122.0
# Name: f, dtype: float64

# %%
#datos de entrenamiento
celcius = temp["c"]
fahrenheit = temp["f"]

#print(fahrenheit)

# %%
#modelo
modelo = tf.keras.Sequential()
modelo.add(tf.keras.layers.Dense(units=1, input_shape=[1]))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#compilar
modelo.compile(optimizer=tf.keras.optimizers.Adam(1.0), loss="mean_squared_error")

#entrenamiento
epocas = modelo.fit(celcius, fahrenheit, epochs=300, verbose=0)
print("Entrenamiento finalizado")
# Out:
# Entrenamiento finalizado

# %%
#probar nuestra IA

import numpy as np
grados = np.array([60])
resp = modelo.predict([grados])
print("El valor en Farenheits es: ", round(resp[0][0], 2))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# El valor en Farenheits es:  140.0
